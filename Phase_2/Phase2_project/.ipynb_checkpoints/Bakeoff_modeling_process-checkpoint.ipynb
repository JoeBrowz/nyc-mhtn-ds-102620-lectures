# %% [markdown]
# # Kings County Housing Prices Bakeoff
#
# Below are a list of steps that you should take while trying to complete your bake-off entry.

# %% [markdown]
# ## Step 1: Read in Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math
from sklearn.preprocessing import StandardScaler
from statsmodels.formula.api import ols
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_selection import SelectKBest, f_regression,mutual_info_regression
from sklearn.feature_selection import RFECV
from sklearn.linear_model import Lasso
import censusgeocode as cg


sns.set(style="darkgrid")

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 50)

# %%
df = pd.read_csv("kc_house_data_train.csv", index_col="Unnamed: 0")

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17290 entries, 0 to 17289
# Data columns (total 21 columns):
# id               17290 non-null int64
# date             17290 non-null object
# price            17290 non-null float64
# bedrooms         17290 non-null int64
# bathrooms        17290 non-null float64
# sqft_living      17290 non-null int64
# sqft_lot         17290 non-null int64
# floors           17290 non-null float64
# waterfront       17290 non-null int64
# view             17290 non-null int64
# condition        17290 non-null int64
# grade            17290 non-null int64
# sqft_above       17290 non-null int64
# sqft_basement    17290 non-null int64
# yr_built         17290 non-null int64
# yr_renovated     17290 non-null int64
# zipcode          17290 non-null int64
# lat              17290 non-null float64
# long             17290 non-null float64
# sqft_living15    17290 non-null int64
# sqft_lot15       17290 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 2.9+ MB
#                id             date      price  bedrooms  bathrooms  \
# 0      2591820310  20141006T000000   365000.0         4       2.25
# 1      7974200820  20140821T000000   865000.0         5       3.00
# 2      7701450110  20140815T000000  1038000.0         4       2.50
# 3      9522300010  20150331T000000  1490000.0         3       3.50
# 4      9510861140  20140714T000000   711000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 17285   627300195  20150303T000000   750000.0         5       2.50
# 17286  8819900270  20140520T000000   440000.0         2       1.75
# 17287  3816300095  20140514T000000   310000.0         3       1.00
# 17288   122069107  20141204T000000   427500.0         3       1.50
# 17289  6703100135  20150116T000000   348000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             2070      8893     2.0           0     0          4      8
# 1             2900      6730     1.0           0     0          5      8
# 2             3770     10893     2.0           0     2          3     11
# 3             4560     14608     2.0           0     2          3     12
# 4             2550      5376     2.0           0     0          3      9
# ...            ...       ...     ...         ...   ...        ...    ...
# 17285         3240      9960     1.0           0     1          3      8
# 17286         1300      4000     2.0           0     0          3      7
# 17287         1050      9876     1.0           0     0          3      7
# 17288         1900     43186     1.5           0     0          4      7
# 17289         1330      6768     1.0           0     0          4      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            2070              0      1986             0    98058  47.4388
# 1            1830           1070      1977             0    98115  47.6784
# 2            3770              0      1997             0    98006  47.5646
# 3            4560              0      1990             0    98034  47.6995
# 4            2550              0      2004             0    98052  47.6647
# ...           ...            ...       ...           ...      ...      ...
# 17285        2020           1220      1958             0    98008  47.5858
# 17286        1300              0      1948             0    98105  47.6687
# 17287        1050              0      1953             0    98028  47.7635
# 17288        1300            600      1971             0    98038  47.4199
# 17289        1330              0      1952             0    98155  47.7366
#
#           long  sqft_living15  sqft_lot15
# 0     -122.162           2390        7700
# 1     -122.285           2370        6283
# 2     -122.129           3710        9685
# 3     -122.228           4050       14226
# 4     -122.083           2250        4050
# ...        ...            ...         ...
# 17285 -122.112           2730       10400
# 17286 -122.288           1350        4013
# 17287 -122.262           1760        9403
# 17288 -121.990           2080      108028
# 17289 -122.319           1320        6910
#
# [17290 rows x 21 columns]

# %%
df.yr_renovated.value_counts()
# Out:
# 0       16564
# 2014       71
# 2007       32
# 2005       32
# 2000       31
#         ...
# 1934        1
# 1959        1
# 1944        1
# 1951        1
# 1948        1
# Name: yr_renovated, Length: 69, dtype: int64

# %% [markdown]
# ## Step 2: Exploratory Data Analysis
#
# Become familiar with the data.  Look to see if there are any extreme values.
#
# Additionally create data visualizations to determine if there are any relationships between your features and your target variables.

# %%
print(df.columns)
ignore_cols = ['id', 'price', 'date']
explore_cols = [x for x in df.columns if x not in ignore_cols]
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(df[explore_cols].values, i) for i in range(df[explore_cols].shape[1])]
vif["features"] = df[explore_cols].columns
vif.round(1)
# Out:
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     VIF Factor       features
# 0         22.5       bedrooms
# 1         28.4      bathrooms
# 2          inf    sqft_living
# 3          2.3       sqft_lot
# 4         16.8         floors
# 5          1.2     waterfront
# 6          1.6           view
# 7         34.5      condition
# 8        147.9          grade
# 9          inf     sqft_above
# 10         inf  sqft_basement
# 11      9547.0       yr_built
# 12         1.2   yr_renovated
# 13   1614130.3        zipcode
# 14    138916.8            lat
# 15   1345606.9           long
# 16        27.2  sqft_living15
# 17         2.5     sqft_lot15

# %%
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(16,30))

for i, column in enumerate(explore_cols):
    sns.scatterplot(data = df, x=column,y='price', ax=axes[i//3, i%3])

# %%
# fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(16,30))

# for i, column in enumerate(explore_cols):
#     sns.histplot(data = df, x=column, ax=axes[i//3, i%3])

# %%
df.zipcode.value_counts()
# Out:
# 98052    474
# 98115    465
# 98103    461
# 98038    455
# 98117    437
#         ...
# 98102     80
# 98010     74
# 98024     65
# 98148     43
# 98039     42
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# ## Step 3: Clean up any issues (extreme values, etc.) with the data.
#
# Remember that you can't just delete rows with extreme values. Similar observations might be present in the holdout data set, and you can't just delete those rows and not have a prediction for it.

# %%
df['bedrooms'].iloc[483] = 4 
df['bathrooms'].iloc[483] =  2.5
df['bedrooms'].iloc[1120] = 5
df['bathrooms'].iloc[1120] =  4
df['bedrooms'].iloc[2430] =


df[df['bedrooms'] == 0]
# Out:
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                id             date      price  bedrooms  bathrooms  \
# 2430   1222029077  20141029T000000   265000.0         0       0.75
# 3032   7849202190  20141223T000000   235000.0         0       0.00
# 3609   2569500210  20141117T000000   339950.0         0       2.50
# 5424   3918400017  20150205T000000   380000.0         0       0.00
# 6409   1453602309  20140805T000000   288000.0         0       1.50
# 9286   2954400190  20140624T000000  1295650.0         0       0.00
# 10067  3980300371  20140926T000000   142000.0         0       0.00
# 10074  2310060040  20140925T000000   240000.0         0       2.50
# 13989  6896300380  20141002T000000   228000.0         0       1.00
# 15733  7849202299  20150218T000000   320000.0         0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 2430           384    213444     1.0           0     0          3      4
# 3032          1470      4800     2.0           0     0          3      7
# 3609          2290      8319     2.0           0     0          3      8
# 5424          1470       979     3.0           0     2          3      8
# 6409          1430      1650     3.0           0     0          3      7
# 9286          4810     28008     2.0           0     0          3     12
# 10067          290     20875     1.0           0     0          1      1
# 10074         1810      5669     2.0           0     0          3      7
# 13989          390      5900     1.0           0     0          2      4
# 15733         1490      7111     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 2430          384              0      2003             0    98070  47.4177
# 3032         1470              0      1996             0    98065  47.5265
# 3609         2290              0      1985             0    98042  47.3473
# 5424         1470              0      2006             0    98133  47.7145
# 6409         1430              0      1999             0    98125  47.7222
# 9286         4810              0      1990             0    98053  47.6642
# 10067         290              0      1963             0    98024  47.5308
# 10074        1810              0      2003             0    98038  47.3493
# 13989         390              0      1953             0    98118  47.5260
# 15733        1490              0      1999             0    98065  47.5261
#
#           long  sqft_living15  sqft_lot15
# 2430  -122.491           1920      224341
# 3032  -121.828           1060        7200
# 3609  -122.151           2500        8751
# 5424  -122.356           1470        1399
# 6409  -122.290           1430        1650
# 9286  -122.069           4740       35061
# 10067 -121.888           1620       22850
# 10074 -122.053           1810        5685
# 13989 -122.261           2170        6000
# 15733 -121.826           1500        4675

# %%
np.log(df['sqft_above'])
# Out:
# 0        7.635304
# 1        7.512071
# 2        8.234830
# 3        8.425078
# 4        7.843849
#            ...
# 17285    7.610853
# 17286    7.170120
# 17287    6.956545
# 17288    7.170120
# 17289    7.192934
# Name: sqft_above, Length: 17290, dtype: float64

# %%
df[df.sqft_living.isin(range(13000,14000))]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 3275  1225069038  20140505T000000  2280000.0         7        8.0
#
#       sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 3275        13540    307752     3.0           0     4          3     12
#
#       sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3275        9410           4130      1999             0    98053  47.6675
#
#          long  sqft_living15  sqft_lot15
# 3275 -121.986           4850      217800

# %%
# df['bedrooms'] = df['bedrooms'].replace({0: df.bedrooms.median()})
df['bedrooms'] = df['bedrooms'].replace({11:4, 33:3})
# df['bathrooms'] = df['bathrooms'].replace({0: df.bathrooms.median()})

# %%
# fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(16,25))

# for i, column in enumerate(explore_cols):
#     sns.boxplot(data = df, x=column, ax=axes[i//3, i%3])

# %%
df.price.plot.box()

# %% [markdown]
# ## Step 4: Generate new features that you think could be important.
#
# After doing this, you will want to go back to steps 2 and 3 to investigate these new features.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['old_charm'] = (2020-df['yr_built'])*df['grade']
df['yrs_old'] = 2020-df.yr_built

# %%
df['age_feature'] = (df['yrs_old'] - 57)**2

# %%
def distance_to(longi, lati):

# %%
len(set(df.zipcode))
# Out:
# 70

# %%
def add_census_tract(dataframe):
    copy = dataframe.copy()
    for elem in copy:
        result = cg.coordinates(x=elem['long'] , y=elem['lat'])
        copy['tract'] = result['2010 Census Blocks'][0]['TRACT']
    return copy

# %%
print(f'unique tracts: {len(set(tracts))}, total items: {len(tracts)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-547dda33c8c0> in <module>()
# ----> 1 print(f'unique tracts: {len(set(tracts))}, total items: {len(tracts)}')
#
# NameError: name 'tracts' is not defined

# %%
df['grade_exp'] = np.exp(df['grade'])

# %%
conditions = [df['grade']< 4, df['grade'].isin(range(4, 11)), df['grade'] > 10]
choices = ['busted', 'aight', 'dope']
df['cond_cat'] = np.select(conditions, choices, default = 'missing')

# %%
df['has_basement'] = np.where(df['sqft_basement'] == 0, 0, 1)

# %%
df['date'] = pd.to_datetime(df['date'], format="%Y%m%dT000000")
df['season'] = (df.date.dt.month%12 + 3)//3
df.groupby(['grade_exp'])['price'].mean().plot()

# %% [markdown]
# ### 4.1) Identify a categorical variable in the data set and create dummy columns.

# %%
season_dum = pd.get_dummies(df['season'], prefix='sn', drop_first=True)
zipcode_dum = pd.get_dummies(df['zipcode'], prefix='zp', drop_first=True)
cond_dum = pd.get_dummies(df['cond_cat'], prefix='condtn', drop_first=True)
df = pd.concat([df, cond_dum, zipcode_dum, season_dum], 1)

# %% [markdown]
# ### 4.2) There is a column that gives the date for when the house was sold, how could this be useful in your model? How might you transform the current column to a more useful feature?

# %%
#your code here

# %% [markdown]
# ### 4.3) There are columns for when the house was built and when it was renovated.  How could you use these columns to create a new column?

# %%
#your code here 
df['last_const'] = np.where(df['yr_renovated']==0, 2020-df['yr_built'],2020-df['yr_renovated'])

# %% [markdown]
# ### <ins>Non-linear transformations</ins>
#
# ### 4.4) Create a polynomial feature for two of your continuous variables.

# %%
df.corr()[df.corr() > .7]
# Out:
#               id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id           1.0      NaN       NaN        NaN          NaN       NaN     NaN
# price        NaN  1.00000       NaN        NaN     0.703540       NaN     NaN
# bedrooms     NaN      NaN       1.0        NaN          NaN       NaN     NaN
# bathrooms    NaN      NaN       NaN   1.000000     0.755859       NaN     NaN
# sqft_living  NaN  0.70354       NaN   0.755859     1.000000       NaN     NaN
# ...          ...      ...       ...        ...          ...       ...     ...
# zp_98199     NaN      NaN       NaN        NaN          NaN       NaN     NaN
# sn_2         NaN      NaN       NaN        NaN          NaN       NaN     NaN
# sn_3         NaN      NaN       NaN        NaN          NaN       NaN     NaN
# sn_4         NaN      NaN       NaN        NaN          NaN       NaN     NaN
# last_const   NaN      NaN       NaN        NaN          NaN       NaN     NaN
#
#              waterfront  view  condition     grade  sqft_above  sqft_basement  \
# id                  NaN   NaN        NaN       NaN         NaN            NaN
# price               NaN   NaN        NaN       NaN         NaN            NaN
# bedrooms            NaN   NaN        NaN       NaN         NaN            NaN
# bathrooms           NaN   NaN        NaN       NaN         NaN            NaN
# sqft_living         NaN   NaN        NaN  0.762929    0.876696            NaN
# ...                 ...   ...        ...       ...         ...            ...
# zp_98199            NaN   NaN        NaN       NaN         NaN            NaN
# sn_2                NaN   NaN        NaN       NaN         NaN            NaN
# sn_3                NaN   NaN        NaN       NaN         NaN            NaN
# sn_4                NaN   NaN        NaN       NaN         NaN            NaN
# last_const          NaN   NaN        NaN       NaN         NaN            NaN
#
#              yr_built  yr_renovated  zipcode  lat  long  sqft_living15  \
# id                NaN           NaN      NaN  NaN   NaN            NaN
# price             NaN           NaN      NaN  NaN   NaN            NaN
# bedrooms          NaN           NaN      NaN  NaN   NaN            NaN
# bathrooms         NaN           NaN      NaN  NaN   NaN            NaN
# sqft_living       NaN           NaN      NaN  NaN   NaN       0.755066
# ...               ...           ...      ...  ...   ...            ...
# zp_98199          NaN           NaN      NaN  NaN   NaN            NaN
# sn_2              NaN           NaN      NaN  NaN   NaN            NaN
# sn_3              NaN           NaN      NaN  NaN   NaN            NaN
# sn_4              NaN           NaN      NaN  NaN   NaN            NaN
# last_const        NaN           NaN      NaN  NaN   NaN            NaN
#
#              sqft_lot15  old_charm   yrs_old  age_feature  has_basement  \
# id                  NaN        NaN       NaN          NaN           NaN
# price               NaN        NaN       NaN          NaN           NaN
# bedrooms            NaN        NaN       NaN          NaN           NaN
# bathrooms           NaN        NaN       NaN          NaN           NaN
# sqft_living         NaN        NaN       NaN          NaN           NaN
# ...                 ...        ...       ...          ...           ...
# zp_98199            NaN        NaN       NaN          NaN           NaN
# sn_2                NaN        NaN       NaN          NaN           NaN
# sn_3                NaN        NaN       NaN          NaN           NaN
# sn_4                NaN        NaN       NaN          NaN           NaN
# last_const          NaN   0.852284  0.910566          NaN           NaN
#
#                season  condtn_busted  condtn_dope  zp_98002  zp_98003  \
# id                NaN            NaN          NaN       NaN       NaN
# price             NaN            NaN          NaN       NaN       NaN
# bedrooms          NaN            NaN          NaN       NaN       NaN
# bathrooms         NaN            NaN          NaN       NaN       NaN
# sqft_living       NaN            NaN          NaN       NaN       NaN
# ...               ...            ...          ...       ...       ...
# zp_98199          NaN            NaN          NaN       NaN       NaN
# sn_2              NaN            NaN          NaN       NaN       NaN
# sn_3              NaN            NaN          NaN       NaN       NaN
# sn_4         0.759381            NaN          NaN       NaN       NaN
# last_const        NaN            NaN          NaN       NaN       NaN
#
#              zp_98004  zp_98005  zp_98006  zp_98007  zp_98008  zp_98010  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98011  zp_98014  zp_98019  zp_98022  zp_98023  zp_98024  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98027  zp_98028  zp_98029  zp_98030  zp_98031  zp_98032  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98033  zp_98034  zp_98038  zp_98039  zp_98040  zp_98042  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98045  zp_98052  zp_98053  zp_98055  zp_98056  zp_98058  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98059  zp_98065  zp_98070  zp_98072  zp_98074  zp_98075  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98077  zp_98092  zp_98102  zp_98103  zp_98105  zp_98106  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98107  zp_98108  zp_98109  zp_98112  zp_98115  zp_98116  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98117  zp_98118  zp_98119  zp_98122  zp_98125  zp_98126  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98133  zp_98136  zp_98144  zp_98146  zp_98148  zp_98155  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98166  zp_98168  zp_98177  zp_98178  zp_98188  zp_98198  \
# id                NaN       NaN       NaN       NaN       NaN       NaN
# price             NaN       NaN       NaN       NaN       NaN       NaN
# bedrooms          NaN       NaN       NaN       NaN       NaN       NaN
# bathrooms         NaN       NaN       NaN       NaN       NaN       NaN
# sqft_living       NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# zp_98199          NaN       NaN       NaN       NaN       NaN       NaN
# sn_2              NaN       NaN       NaN       NaN       NaN       NaN
# sn_3              NaN       NaN       NaN       NaN       NaN       NaN
# sn_4              NaN       NaN       NaN       NaN       NaN       NaN
# last_const        NaN       NaN       NaN       NaN       NaN       NaN
#
#              zp_98199  sn_2  sn_3  sn_4  last_const
# id                NaN   NaN   NaN   NaN         NaN
# price             NaN   NaN   NaN   NaN         NaN
# bedrooms          NaN   NaN   NaN   NaN         NaN
# bathrooms         NaN   NaN   NaN   NaN         NaN
# sqft_living       NaN   NaN   NaN   NaN         NaN
# ...               ...   ...   ...   ...         ...
# zp_98199          1.0   NaN   NaN   NaN         NaN
# sn_2              NaN   1.0   NaN   NaN         NaN
# sn_3              NaN   NaN   1.0   NaN         NaN
# sn_4              NaN   NaN   NaN   1.0         NaN
# last_const        NaN   NaN   NaN   NaN         1.0
#
# [100 rows x 100 columns]

# %% [markdown]
# ### 4.5) Create an interaction feature between a binary variable (dummy variable) and a continuous variable.

# %%
# your code here

# %% [markdown]
# ## Step 5: Train-Test Split
#
# If you plan on doing any scaling of your data, make sure it is done at the appropriate time.

# %% [markdown]
# ### 5.1) Perform a train-test split of the data.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view',
#        ...
#        'zp_98168', 'zp_98177', 'zp_98178', 'zp_98188', 'zp_98198', 'zp_98199',
#        'sn_2', 'sn_3', 'sn_4', 'last_const'],
#       dtype='object', length=102)

# %%
leave_out = ['id', 'date', 'season', 'price', 'bedrooms', 'sqft_lot', 'cond_cat', 
             'floors', 'view', 'condition', 'grade', 'sqft_above', 
             'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_lot15', 'last_const']
features = [x for x in df.columns if x not in leave_out] 
features
# Out:
# ['bathrooms',
#  'sqft_living',
#  'waterfront',
#  'sqft_living15',
#  'old_charm',
#  'yrs_old',
#  'age_feature',
#  'has_basement',
#  'condtn_busted',
#  'condtn_dope',
#  'zp_98002',
#  'zp_98003',
#  'zp_98004',
#  'zp_98005',
#  'zp_98006',
#  'zp_98007',
#  'zp_98008',
#  'zp_98010',
#  'zp_98011',
#  'zp_98014',
#  'zp_98019',
#  'zp_98022',
#  'zp_98023',
#  'zp_98024',
#  'zp_98027',
#  'zp_98028',
#  'zp_98029',
#  'zp_98030',
#  'zp_98031',
#  'zp_98032',
#  'zp_98033',
#  'zp_98034',
#  'zp_98038',
#  'zp_98039',
#  'zp_98040',
#  'zp_98042',
#  'zp_98045',
#  'zp_98052',
#  'zp_98053',
#  'zp_98055',
#  'zp_98056',
#  'zp_98058',
#  'zp_98059',
#  'zp_98065',
#  'zp_98070',
#  'zp_98072',
#  'zp_98074',
#  'zp_98075',
#  'zp_98077',
#  'zp_98092',
#  'zp_98102',
#  'zp_98103',
#  'zp_98105',
#  'zp_98106',
#  'zp_98107',
#  'zp_98108',
#  'zp_98109',
#  'zp_98112',
#  'zp_98115',
#  'zp_98116',
#  'zp_98117',
#  'zp_98118',
#  'zp_98119',
#  'zp_98122',
#  'zp_98125',
#  'zp_98126',
#  'zp_98133',
#  'zp_98136',
#  'zp_98144',
#  'zp_98146',
#  'zp_98148',
#  'zp_98155',
#  'zp_98166',
#  'zp_98168',
#  'zp_98177',
#  'zp_98178',
#  'zp_98188',
#  'zp_98198',
#  'zp_98199',
#  'sn_2',
#  'sn_3',
#  'sn_4']

# %%
#your code here 
X_train, X_test, y_train, y_test = train_test_split(df[features], df['price'], random_state=57,test_size=0.2)

print("Training set - Features: ", X_train.shape, "Target: ", y_train.shape)
print("Training set - Features: ", X_test.shape, "Target: ",y_test.shape)
# Out:
# Training set - Features:  (13832, 82) Target:  (13832,)
# Training set - Features:  (3458, 82) Target:  (3458,)

# %% [markdown]
# ### 5.2) Fit your scaler to training the data.

# %%
scaler = StandardScaler()

scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ### 5.3) Transform the testing set with the scaler.

# %%
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=df[features].columns)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=df[features].columns)

# %% [markdown]
# ### 5.4) Fit the model to the training data.

# %%
lm = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# ### 5.5) Use the model to predict on the training set and the test set.

# %%
y_train_pred = lm.predict(X_train)

y_test_pred = lm.predict(X_test)

# %% [markdown]
# ### 5.6) Evaluate the training and test predictions using RMSE.

# %%
train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))

test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))

# %% [markdown]
# ### 5.7) Determine if your model is overfit.

# %%
print(f'Training: {int(train_rmse)} vs Testing: {int(test_rmse)}')
# Out:
# Training: 167586 vs Testing: 157612

# %%
sns.residplot(x = y_test, y= y_test_pred, lowess=True, color = "g")

# %%
print(df.sqft_lot.mean())
abs(y_test-y_test_pred).idxmax()
# Out:
# 15243.3998843262
# 4177

# %%
df.iloc[10067]
# Out:
# id                     3980300371
# date          2014-09-26 00:00:00
# price                      142000
# bedrooms                        0
# bathrooms                       0
#                      ...
# zp_98199                        0
# sn_2                            0
# sn_3                            0
# sn_4                            1
# last_const                     57
# Name: 10067, Length: 102, dtype: object

# %% [markdown]
# ## Step 6: Utilize some different feature selection techniques before or in conjuction with fitting your models.

# %% [markdown]
# ### 6.1) Utilize a filter method to identify some features to remove from the model.

# %% [markdown]
# ### 6.2) After removing the features, re-run Step 5 and see if your new model performs better than the old model.

# %%
poly_2 = PolynomialFeatures(degree=2, include_bias=False)
poly2_data = poly_2.fit_transform(df[features])
poly2_columns = poly_2.get_feature_names(df[features].columns)
df_poly2 = pd.DataFrame(poly2_data, columns=poly2_columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_poly2, df['price'], random_state=9,test_size=0.2)

# %%
scaler2 = StandardScaler()

scaler2.fit(X_train)

X_train = pd.DataFrame(data=scaler2.transform(X_train), columns=df_poly2.columns)

X_test = pd.DataFrame(data=scaler2.transform(X_test), columns=df_poly2.columns)

# %%
# instantiate a linear regression object
lm_2 = LinearRegression()

#fit the linear regression to the data
lm_2 = lm_2.fit(X_train, y_train)

y_train_pred = lm_2.predict(X_train)

train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))

print('Training Root Mean Squared Error:' , train_rmse)
# Out:
# Training Root Mean Squared Error: 112109.61651904236

# %%
y_pred = lm_2.predict(X_test)

test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Training: ', int(train_rmse), "vs. Testing: ", int(test_rmse))
# Out:
# Training:  112109 vs. Testing:  7237016476224963

# %%
abs(y_train-y_train_pred).idxmax()
# Out:
# 16814

# %%
df.iloc[14477]
# Out:
# id                     3835500195
# date          2014-06-18 00:00:00
# price                   4.489e+06
# bedrooms                        4
# bathrooms                       3
#                      ...
# zp_98199                        0
# sn_2                            0
# sn_3                            1
# sn_4                            0
# last_const                     19
# Name: 14477, Length: 102, dtype: object

# %%
poly_3 = PolynomialFeatures(degree=3, include_bias=False)
poly3_data = poly_3.fit_transform(df[features])
poly3_columns = poly_3.get_feature_names(df[features].columns)
df_poly3 = pd.DataFrame(poly3_data, columns=poly3_columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_poly3, df['price'], random_state=6, test_size=0.2)
scaler3 = StandardScaler()
# fit the scaler to the training data
scaler3.fit(X_train)

#transform the training data
X_train = pd.DataFrame(data=scaler3.transform(X_train), columns=df_poly3.columns)

#transform the testing dat
X_test = pd.DataFrame(data=scaler3.transform(X_test), columns=df_poly3.columns)

# %%
# instantiate a linear regression object
lm_3 = LinearRegression()

#fit the linear regression to the data
lm_3 = lm_3.fit(X_train, y_train)

y_train_pred = lm_3.predict(X_train)

train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))

# %%
# use fitted model to predict on test data
y_pred = lm_3.predict(X_test)

test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Testing Root Mean Squared Error:' , test_rmse)


print('Training: ', int(train_rmse), "vs. Testing: ", "{:,}".format(test_rmse))

# %% [markdown]
# ### Feature Selection

# %%
selector = SelectKBest(f_regression, k=20)

selector.fit(X_train, y_train)
# Out:
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:299: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# SelectKBest(k=20, score_func=<function f_regression at 0x7fd2261b2c80>)

# %%
selected_columns = X_train.columns[selector.get_support()]
removed_columns = X_train.columns[~selector.get_support()]

# %%
#instantiate a linear regression object
lm_kbest = LinearRegression()

#fit the linear regression to the data
lm_kbest.fit(X_train[selected_columns], y_train)

y_train_kbest = lm_kbest.predict(X_train[selected_columns])


trainK_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_kbest))


print('Training Root Mean Squared Error:' , trainK_rmse)

y_kbest = lm_kbest.predict(X_test[selected_columns])

testK_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_kbest))

print('Testing Root Mean Squared Error:' , testK_rmse)
# Out:
# Training Root Mean Squared Error: 221474.4837325999
# Testing Root Mean Squared Error: 209878.3000249412

# %% [markdown]
# ### Wrapper Method

# %%
ols = linear_model.LinearRegression()

# %%
selector = RFECV(estimator=ols, step=1, cv=2, scoring='neg_mean_squared_error', n_jobs=-1)

selector.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-d3b43ab50425> in <module>()
#       1 selector = RFECV(estimator=ols, step=1, cv=2, scoring='neg_mean_squared_error', n_jobs=-1)
#       2
# ----> 3 selector.fit(X_train, y_train)
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/feature_selection/rfe.py in fit(self, X, y, groups)
#     520         scores = parallel(
#     521             func(rfe, self.estimator, X, y, train, test, scorer)
# --> 522             for train, test in cv.split(X, y, groups))
#     523
#     524         scores = np.sum(scores, axis=0)
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
selected_rfe = X_train.columns[selector.support_]
removed_rfe = X_train.columns[~selector.support_]

# %%
lm_rfe = LinearRegression()

#fit the linear regression to the data
lm_rfe = lm_rfe.fit(X_train[selected_rfe], y_train)

y_rfe = lm_rfe.predict(X_train[selected_rfe])

trainRFE_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_rfe))

print('Training Root Mean Squared Error:' , trainRFE_rmse)

y_pred_rfe = lm_rfe.predict(X_test[selected_rfe])

testRFE_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred_rfe))

print('Testing Root Mean Squared Error:' , testRFE_rmse)

# %% [markdown]
# ### Lasso

# %%
lasso = Lasso(alpha=750, normalize=False)

lasso.fit(X_train,y_train)

y_train_pred = lasso.predict(X_train)
y_pred = lasso.predict(X_test)

train_rmse_lasso01 = metrics.mean_absolute_error(y_train, y_train_pred)
test_rmse_lasso01 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(train_rmse_lasso01) )
print('Testing Error: '+ str(test_rmse_lasso01) )
# Out:
# Training Error: 73529.85613430454
# Testing Error: 126762.56086995643
# /Users/browz/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124209834072.5, tolerance: 194982925380.51126
#   positive)

# %% [markdown]
# ## Step 7: Evaluate your different models in order to determine the best model overall.

# %% [markdown]
# ## Step 8:  Refit your best model to the entire dataset.

# %% [markdown]
# ## Step 9: Save your final model using pickle.
#
# https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/

# %%
pickle_out = open("")
